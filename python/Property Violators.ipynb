# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import stats

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-08a9ffbeb654> in <module>()
# ----> 1 pd.low
#
# AttributeError: module 'pandas' has no attribute 'low'

# %%
data = pd.read_csv('Property_Violations.csv', low_memory=False)

# %%
df = pd.DataFrame(data)

# %%
df.tail()
# Out:
#         ﻿Property Violation ID     Case ID  Status Case Opened Date  \
# 401108                 1025557  2010290250  Closed       08/11/2010
# 401109                 1086494  2013044161  Closed       04/04/2013
# 401110                 1078098  2012141472  Closed       10/08/2012
# 401111                 1004665  2010020288  Closed       01/14/2010
# 401112                 1055208  2011236094  Closed       12/23/2011
#
#        Case Closed Date  Days Open Violation Code  \
# 401108       11/12/2010         93      NSWLTRASH
# 401109       09/19/2013        168      NSWLTRASH
# 401110       11/26/2012         49      NSWLTRASH
# 401111       09/27/2011        621      NSWLTRASH
# 401112       02/29/2012         68       NSGRAF05
#
#                      Violation Description Ordinance Number  \
# 401108  LITTER, TRASH, REFUSE, AND RUBBISH       48-25 C.O.
# 401109  LITTER, TRASH, REFUSE, AND RUBBISH       48-25 C.O.
# 401110  LITTER, TRASH, REFUSE, AND RUBBISH       48-25 C.O.
# ...

# %%
#data = data.drop_duplicates()

# %%
print(data.count())
# Out:
# ﻿Property Violation ID        401113
# Case ID                       401113
# Status                        401113
# Case Opened Date              401113
# Case Closed Date              281927
# Days Open                     401113
# Violation Code                401113
# Violation Description         401113
# Ordinance Number              401113
# Ordinance Chapter             401113
# Violation Entry Date          401112
# Address                       401108
# County                        400947
# State                         401109
# Zip Code                      401008
# KIVA PIN                      401113
# Council District              400445
# Police Patrol Area            400445
# Inspection Area               397253
# Neighborhood                  400274
# Mapping Location (city)            0
# Mapping Location (address)    401108
# Mapping Location (zip)        401008
# Mapping Location (state)      401109
# Mapping Location              398100
# dtype: int64

# %%
print(data)
# Out:
#         ﻿Property Violation ID     Case ID  Status Case Opened Date  \
# 0                      1124587  2014133868  Closed       10/17/2014
# 1                      1124587  2014133868  Closed       10/17/2014
# 2                      1124587  2014133868  Closed       10/17/2014
# 3                      1124587  2014133868  Closed       10/17/2014
# 4                      1023860  2010261829  Closed       07/19/2010
# 5                      1131701  2015031229  Closed       03/27/2015
# 6                      1126208  2014146905  Closed       11/20/2014
# 7                      1136477  2015060254  Closed       06/01/2015
# 8                      1097837  2013110660  Closed       08/07/2013
# 9                      1135112  2015051240  Closed       05/13/2015
# 10                     1113554  2014066191  Closed       05/28/2014
# 11                     1090379  2013067706  Closed       05/21/2013
# 12                     1132991  2015040361  Closed       04/20/2015
# ...
